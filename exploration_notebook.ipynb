# %%
from ultralytics import YOLO
import cv2
import torch

# Load a model
pose_model = YOLO("models/yolo11n-pose.pt")
detect_model = YOLO("models/detect.pt")

# %%
# Open the video file
video_path = "sample_front.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        pose_results = pose_model(frame)
        detect_results = detect_model(frame)

        # Visualize the results on the frame
        pose_annotated = pose_results[0].plot()
        detect_annotated = detect_results[0].plot()

        # Overlay annotated frames
        annotated_frame = cv2.addWeighted(pose_annotated, 0.5, detect_annotated, 0.5, 0)

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 person, 69.8ms
# Speed: 3.0ms preprocess, 69.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.7ms
# Speed: 2.3ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.1ms
# Speed: 2.6ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 38.0ms
# Speed: 1.3ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 33.4ms
# Speed: 1.2ms preprocess, 33.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 1.7ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 63.5ms
# Speed: 1.7ms preprocess, 63.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.6ms
# Speed: 1.6ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.1ms
# Speed: 1.5ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.0ms
# Speed: 1.4ms preprocess, 45.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.0ms
# Speed: 1.4ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.6ms
# Speed: 1.3ms preprocess, 45.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.5ms
# Speed: 1.7ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.4ms
# Speed: 1.9ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.0ms
# Speed: 1.8ms preprocess, 48.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.0ms
# Speed: 1.2ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.2ms
# Speed: 2.0ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.0ms
# Speed: 1.3ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.5ms
# Speed: 1.5ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 38.4ms
# Speed: 1.2ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.7ms
# Speed: 1.7ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 56.6ms
# Speed: 1.3ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.2ms
# Speed: 1.3ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.3ms
# Speed: 1.7ms preprocess, 46.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 bars, 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.5ms
# Speed: 2.1ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 bars, 1 person, 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 43.2ms
# Speed: 1.7ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49
ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 41.3ms
# ...
# 0: 640x384 1 person, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.6ms
# Speed: 1.8ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.3ms
# Speed: 1.7ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.2ms
# Speed: 1.9ms preprocess, 49.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.4ms
# Speed: 1.4ms preprocess, 48.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.8ms
# Speed: 1.7ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 1.7ms preprocess, 47.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.7ms
# Speed: 1.8ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 60.1ms
# Speed: 1.7ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.7ms
# Speed: 1.8ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 1.3ms preprocess, 47.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 51.7ms
# Speed: 1.9ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.2ms
# Speed: 1.5ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.2ms
# Speed: 1.7ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.9ms
# Speed: 1.8ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 45.4ms
# Speed: 2.2ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 49.6ms
# Speed: 1.4ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.7ms
# Speed: 1.7ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.1ms
# Speed: 1.4ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.8ms
# Speed: 1.9ms preprocess, 47.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 1.9ms preprocess, 47.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.2ms
# Speed: 1.3ms preprocess, 45.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 41.2ms
# Speed: 1.3ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.4ms
# Speed: 1.2ms preprocess, 47.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 56.8ms
# Speed: 3.9ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 44.4ms
# Speed: 1.3ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.3ms
# Speed: 1.2ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.9ms
# Speed: 1.7ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 39.0ms
# Speed: 1.3ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 46.7ms
# Speed: 1.8ms preprocess, 46.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)

# %%
pose_results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         [[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         [[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         ...,
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]],
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]],
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]]], dtype=uint8)
#  orig_shape: (1280, 720)
#  path: 'image0.jpg'
#  probs: None
#  save_dir: 'runs\\pose\\predict'
#  speed: {'preprocess': 1.43420000676997, 'inference': 50.18019999261014, 'postprocess': 0.9157000167760998}]

# %%
pose_results[0].keypoints.data
# Out:
# tensor([[[3.4592e+02, 4.7591e+02, 9.8805e-01],
#          [3.6553e+02, 4.5869e+02, 9.8924e-01],
#          [3.3415e+02, 4.5857e+02, 8.8440e-01],
#          [4.0683e+02, 4.6538e+02, 9.7442e-01],
#          [0.0000e+00, 0.0000e+00, 2.4847e-01],
#          [4.5739e+02, 5.7038e+02, 9.9882e-01],
#          [3.1205e+02, 5.6708e+02, 9.9058e-01],
#          [4.9573e+02, 7.0065e+02, 9.9370e-01],
#          [2.9750e+02, 6.8727e+02, 8.9018e-01],
#          [5.1039e+02, 8.0501e+02, 9.8697e-01],
#          [2.9840e+02, 7.9071e+02, 8.7687e-01],
#          [4.2727e+02, 8.2340e+02, 9.9978e-01],
#          [3.3304e+02, 8.1967e+02, 9.9932e-01],
#          [4.1431e+02, 1.0005e+03, 9.9949e-01],
#          [3.1224e+02, 9.9912e+02, 9.9853e-01],
#          [4.0342e+02, 1.1516e+03, 9.9587e-01],
#          [3.2327e+02, 1.1519e+03, 9.9239e-01]]])

# %%
keypoints = torch.tensor(pose_results[0].keypoints.xy)
keypoints[0]
# Out:
# C:\Users\Roydon\AppData\Local\Temp\ipykernel_6696\986057603.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   keypoints = torch.tensor(pose_results[0].keypoints.xy)
# tensor([[ 345.9173,  475.9119],
#         [ 365.5261,  458.6903],
#         [ 334.1494,  458.5687],
#         [ 406.8260,  465.3811],
#         [   0.0000,    0.0000],
#         [ 457.3876,  570.3845],
#         [ 312.0522,  567.0842],
#         [ 495.7341,  700.6537],
#         [ 297.4963,  687.2670],
#         [ 510.3861,  805.0095],
#         [ 298.4033,  790.7139],
#         [ 427.2724,  823.3993],
#         [ 333.0393,  819.6724],
#         [ 414.3120, 1000.4695],
#         [ 312.2359,  999.1199],
#         [ 403.4224, 1151.5669],
#         [ 323.2685, 1151.9468]])

# %%
left_shoulder = keypoints[0,5]
right_shoulder = keypoints[0,6]
left_ankle = keypoints[0,15]
right_ankle = keypoints[0,16]

# %%
right_ankle
# Out:
# tensor([ 323.2685, 1151.9468])
