# %%
from ultralytics import YOLO
import cv2
import torch

# Load a model
pose_model = YOLO("models/yolo11n-pose.pt")
detect_model = YOLO("models/detect.pt")

# %%
# Open the video file
video_path = "sample_front.mp4"
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
width  = cap.get(cv2.CAP_PROP_FRAME_WIDTH)   # float
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output = cv2.VideoWriter("output.mp4", fourcc, fps,(int(width),int(height)))

# Loop through the video frames
init = False
counted = False
prev_below = False
count = 0
frame_count = 0
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    if not success:
        break  # Exit if the video ends

    frame_count += 1
    if frame_count % 2 != 0:
        continue

    if success:
        # Run YOLO inference on the frame
        pose_results = pose_model(frame)
        pose_keypoints = torch.tensor(pose_results[0].keypoints.xy)

        # Run detection till initialisation (assumes fixed camera)
        if init == False:
            detect_results = detect_model(frame)
            left_wrist = pose_keypoints[0,9]
            right_wrist = pose_keypoints[0,10]

            # Extract 'bar' bounding boxes
            bar_boxes = []
            for box, cls in zip(detect_results[0].boxes.xyxy, detect_results[0].boxes.cls):
                if int(cls) == 0:  # class index 0 corresponds to 'bar'
                    bar_boxes.append(box)

            # Visualize the results on the frame
            pose_annotated = pose_results[0].plot()
            detect_annotated = detect_results[0].plot()

            # Overlay annotated frames
            annotated_frame = cv2.addWeighted(pose_annotated, 0.5, detect_annotated, 0.5, 0)

            # Function to check if a point is inside a bounding box
            def is_inside_box(point, box):
                x, y = point
                x1, y1, x2, y2 = box
                return x1 <= x <= x2 and y1 <= y <= y2

            # Check if both wrists are inside any bar bounding box
            for bar_box in bar_boxes:
                if is_inside_box(left_wrist, bar_box) and is_inside_box(right_wrist, bar_box):
                    x1, y1, x2, y2 = map(int, bar_box)
                    mid_y = (y1 + y2) // 2  # Midpoint of the bounding box height
                    init = True
                    break

        else:
            cv2.line(frame, (x1, mid_y), (x2, mid_y), (0, 255, 0), 3)  # Green line
            annotated_frame = pose_results[0].plot()

            left_ear = pose_keypoints[0, 3]
            right_ear = pose_keypoints[0, 4]
            if left_ear[1].item() < mid_y and right_ear[1].item() < mid_y and not counted:
                counted = True
                count += 1

            # Reset counted only if the head stays below mid_y for multiple frames
            elif left_ear[1].item() > mid_y and right_ear[1].item() > mid_y:
                if prev_below:  # Only reset if it was below previously
                    counted = False  
                prev_below = True  # Mark that it was below mid_y
            else:
                prev_below = False  # Reset tracking if it's in an in-between state
  
        # inserting text on video 
        font = cv2.FONT_HERSHEY_SIMPLEX 
        cv2.putText(annotated_frame, f'Bar initialised: {init}', (50, 50), font, 1, (0, 255, 255), 1, cv2.LINE_4) 
        cv2.putText(annotated_frame, f'Reps: {count}', (50, 90), font, 1, (0, 255, 255), 2, cv2.LINE_4) 


        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)
        output.write(annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
output.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 person, 156.0ms
# Speed: 5.3ms preprocess, 156.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 95.3ms
# Speed: 2.4ms preprocess, 95.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# C:\Users\Roydon\AppData\Local\Temp\ipykernel_29652\2587821155.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pose_keypoints = torch.tensor(pose_results[0].keypoints.xy)
# 0: 640x384 1 person, 104.9ms
# Speed: 5.3ms preprocess, 104.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 97.1ms
# Speed: 2.4ms preprocess, 97.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 106.5ms
# Speed: 3.1ms preprocess, 106.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 87.1ms
# Speed: 2.6ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.0ms
# Speed: 2.3ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 81.6ms
# Speed: 1.8ms preprocess, 81.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.8ms
# Speed: 2.6ms preprocess, 91.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 80.4ms
# Speed: 2.6ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.8ms
# Speed: 1.9ms preprocess, 89.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 71.3ms
# Speed: 2.1ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.6ms
# Speed: 2.6ms preprocess, 82.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 82.6ms
# Speed: 2.3ms preprocess, 82.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 98.0ms
# Speed: 2.4ms preprocess, 98.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 73.4ms
# Speed: 2.7ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.2ms
# Speed: 1.9ms preprocess, 83.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 72.1ms
# Speed: 2.2ms preprocess, 72.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.1ms preprocess, 85.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 77.0ms
# Speed: 2.3ms preprocess, 77.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 1.9ms preprocess, 85.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 75.9ms
# Speed: 2.7ms preprocess, 75.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.3ms preprocess, 85.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 80.0ms
# Speed: 2.4ms preprocess, 80.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.1ms
# Speed: 2.7ms preprocess, 92.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 81.2ms
# Speed: 2.2ms preprocess, 81.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 94.5ms
# Speed: 2.5ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 77.3ms
# Speed: 2.4ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.2ms
# Speed: 2.1ms preprocess, 83.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.0ms
# Speed: 2.4ms preprocess, 82.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 73.6ms
# Speed: 2.1ms preprocess, 73.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 78.2ms
# Speed: 1.9ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.0ms
# Speed: 2.7ms preprocess, 81.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.0ms
# Speed: 2.1ms preprocess, 93.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 77.7ms
# Speed: 2.6ms preprocess, 77.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.1ms
# Speed: 2.0ms preprocess, 89.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.6ms
# Speed: 2.6ms preprocess, 90.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 78.1ms
# Speed: 2.5ms preprocess, 78.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 95.2ms
# Speed: 2.6ms preprocess, 95.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 2 persons, 81.4ms
# Speed: 1.9ms preprocess, 81.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.6ms
# Speed: 2.1ms preprocess, 85.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 79.8ms
# Speed: 2.3ms preprocess, 79.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.9ms
# Speed: 2.4ms preprocess, 89.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 79.2ms
# Speed: 2.6ms preprocess, 79.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.0ms
# Speed: 2.9ms preprocess, 91.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.8ms
# Speed: 2.8ms preprocess, 90.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 95.4ms
# Speed: 2.4ms preprocess, 95.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 87.3ms
# Speed: 4.3ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 104.1ms
# Speed: 2.6ms preprocess, 104.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 82.9ms
# Speed: 2.3ms preprocess, 82.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 82.1ms
# Speed: 2.5ms preprocess, 82.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 106.5ms
# Speed: 2.4ms preprocess, 106.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 103.9ms
# Speed: 2.5ms preprocess, 103.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 98.8ms
# Speed: 2.5ms preprocess, 98.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 90.3ms
# Speed: 2.4ms preprocess, 90.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 107.3ms
# Speed: 2.0ms preprocess, 107.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 83.9ms
# Speed: 1.8ms preprocess, 83.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 99.4ms
# Speed: 2.6ms preprocess, 99.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 72.0ms
# Speed: 1.9ms preprocess, 72.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 102.4ms
# Speed: 3.2ms preprocess, 102.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 68.3ms
# Speed: 1.8ms preprocess, 68.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.4ms
# Speed: 2.5ms preprocess, 84.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 2.6ms preprocess, 88.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.6ms
# Speed: 2.3ms preprocess, 76.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.3ms
# Speed: 2.8ms preprocess, 90.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 73.1ms
# Speed: 2.4ms preprocess, 73.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 74.1ms
# Speed: 1.9ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.1ms
# Speed: 2.1ms preprocess, 87.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 73.9ms
# Speed: 2.4ms preprocess, 73.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 80.1ms
# Speed: 2.5ms preprocess, 80.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.3ms preprocess, 88.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 82.3ms
# Speed: 2.5ms preprocess, 82.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.5ms
# Speed: 2.4ms preprocess, 90.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 81.1ms
# Speed: 2.6ms preprocess, 81.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 94.3ms
# Speed: 2.4ms preprocess, 94.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 76.7ms
# Speed: 2.3ms preprocess, 76.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.8ms preprocess, 87.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 79.2ms
# Speed: 2.2ms preprocess, 79.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.4ms preprocess, 86.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 79.5ms
# Speed: 2.7ms preprocess, 79.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 86.1ms
# Speed: 2.1ms preprocess, 86.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 80.0ms
# Speed: 2.3ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.2ms
# Speed: 2.1ms preprocess, 91.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.5ms preprocess, 87.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 75.6ms
# Speed: 2.2ms preprocess, 75.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.8ms
# Speed: 2.0ms preprocess, 85.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 75.4ms
# Speed: 2.2ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.9ms
# Speed: 2.4ms preprocess, 93.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.4ms
# Speed: 1.9ms preprocess, 76.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 77.9ms
# Speed: 2.3ms preprocess, 77.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.8ms
# Speed: 2.5ms preprocess, 89.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 80.5ms
# Speed: 2.1ms preprocess, 80.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 77.8ms
# Speed: 3.1ms preprocess, 77.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 108.8ms
# Speed: 2.2ms preprocess, 108.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 87.2ms
# Speed: 3.5ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.5ms
# Speed: 1.9ms preprocess, 82.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 71.7ms
# Speed: 2.5ms preprocess, 71.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.2ms
# Speed: 2.5ms preprocess, 84.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 78.1ms
# Speed: 2.1ms preprocess, 78.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.5ms preprocess, 86.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 79.3ms
# Speed: 1.9ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 78.2ms
# Speed: 2.7ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.7ms
# Speed: 2.4ms preprocess, 86.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 82.5ms
# Speed: 2.4ms preprocess, 82.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.2ms
# Speed: 2.1ms preprocess, 89.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 81.6ms
# Speed: 1.9ms preprocess, 81.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.6ms
# Speed: 2.7ms preprocess, 88.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 81.9ms
# Speed: 1.9ms preprocess, 81.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.6ms preprocess, 86.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.9ms
# Speed: 2.6ms preprocess, 90.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 82.5ms
# Speed: 2.1ms preprocess, 82.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.5ms
# Speed: 2.5ms preprocess, 82.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.2ms
# Speed: 2.5ms preprocess, 81.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.5ms
# Speed: 1.9ms preprocess, 76.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.4ms
# Speed: 2.1ms preprocess, 91.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.2ms
# Speed: 2.8ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.8ms
# Speed: 2.4ms preprocess, 83.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 81.5ms
# Speed: 2.4ms preprocess, 81.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 73.6ms
# Speed: 1.9ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.5ms preprocess, 86.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 74.4ms
# Speed: 2.5ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.2ms preprocess, 86.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 76.2ms
# Speed: 2.5ms preprocess, 76.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.6ms
# Speed: 2.7ms preprocess, 89.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 78.8ms
# Speed: 2.4ms preprocess, 78.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.1ms
# Speed: 2.1ms preprocess, 84.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 80.0ms
# Speed: 2.4ms preprocess, 80.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.0ms
# Speed: 2.1ms preprocess, 84.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 80.1ms
# Speed: 2.6ms preprocess, 80.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.6ms
# Speed: 2.5ms preprocess, 91.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 83.8ms
# Speed: 2.9ms preprocess, 83.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.3ms
# Speed: 2.4ms preprocess, 91.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 72.2ms
# Speed: 2.2ms preprocess, 72.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.2ms
# Speed: 2.0ms preprocess, 84.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 72.5ms
# Speed: 2.2ms preprocess, 72.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.8ms
# Speed: 2.5ms preprocess, 84.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 75.8ms
# Speed: 2.7ms preprocess, 75.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.7ms
# Speed: 2.5ms preprocess, 85.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.4ms
# Speed: 2.2ms preprocess, 84.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.6ms preprocess, 86.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 78.4ms
# Speed: 3.2ms preprocess, 78.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.2ms
# Speed: 2.5ms preprocess, 85.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 79.1ms
# Speed: 2.2ms preprocess, 79.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 78.6ms
# Speed: 2.3ms preprocess, 78.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.0ms
# Speed: 2.4ms preprocess, 90.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 74.0ms
# Speed: 2.1ms preprocess, 74.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.5ms preprocess, 86.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 bars, 1 person, 79.3ms
# Speed: 2.4ms preprocess, 79.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.9ms
# Speed: 2.8ms preprocess, 90.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.5ms
# Speed: 2.6ms preprocess, 93.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 74.8ms
# Speed: 2.6ms preprocess, 74.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 2.4ms preprocess, 88.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bar, 1 person, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.1ms preprocess, 86.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 2.3ms preprocess, 84.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.0ms
# Speed: 2.6ms preprocess, 89.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.3ms preprocess, 89.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.0ms
# Speed: 2.3ms preprocess, 88.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.8ms
# Speed: 2.1ms preprocess, 89.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.5ms
# Speed: 2.9ms preprocess, 88.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 96.5ms
# Speed: 2.1ms preprocess, 96.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.7ms preprocess, 86.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.5ms
# Speed: 2.3ms preprocess, 84.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.8ms
# Speed: 2.8ms preprocess, 92.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.3ms preprocess, 86.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.7ms
# Speed: 2.6ms preprocess, 88.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.6ms
# Speed: 2.5ms preprocess, 89.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.4ms
# Speed: 2.0ms preprocess, 89.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.6ms
# Speed: 2.6ms preprocess, 93.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.6ms preprocess, 87.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.5ms
# Speed: 2.3ms preprocess, 82.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.4ms preprocess, 86.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.2ms
# Speed: 2.9ms preprocess, 81.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.5ms
# Speed: 2.4ms preprocess, 85.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.2ms
# Speed: 2.5ms preprocess, 87.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 112.4ms
# Speed: 2.4ms preprocess, 112.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 1.8ms preprocess, 85.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.1ms
# Speed: 2.0ms preprocess, 85.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 80.8ms
# Speed: 2.6ms preprocess, 80.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.5ms preprocess, 84.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.3ms preprocess, 85.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.7ms
# Speed: 2.7ms preprocess, 89.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.3ms
# Speed: 2.5ms preprocess, 87.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.5ms preprocess, 89.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.0ms
# Speed: 2.4ms preprocess, 92.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.0ms
# Speed: 2.1ms preprocess, 88.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# Speed: 2.4ms preprocess, 87.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.8ms
# Speed: 2.1ms preprocess, 88.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.5ms preprocess, 86.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.9ms
# Speed: 2.1ms preprocess, 85.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.9ms
# Speed: 2.5ms preprocess, 85.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.9ms
# Speed: 2.2ms preprocess, 83.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.1ms
# Speed: 2.0ms preprocess, 82.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.7ms
# Speed: 2.5ms preprocess, 87.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.3ms preprocess, 88.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.5ms
# Speed: 2.7ms preprocess, 88.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.2ms
# Speed: 2.1ms preprocess, 87.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.8ms
# Speed: 2.5ms preprocess, 85.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.3ms preprocess, 86.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.7ms
# Speed: 2.1ms preprocess, 85.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.7ms preprocess, 84.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.5ms
# Speed: 2.5ms preprocess, 88.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.5ms
# Speed: 2.3ms preprocess, 90.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.2ms
# Speed: 2.5ms preprocess, 90.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 2.8ms preprocess, 84.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.8ms
# Speed: 2.3ms preprocess, 88.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.3ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.7ms
# Speed: 2.3ms preprocess, 87.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.5ms preprocess, 84.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.5ms
# Speed: 2.3ms preprocess, 88.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.0ms
# Speed: 2.5ms preprocess, 88.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 2.4ms preprocess, 88.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.6ms
# Speed: 2.1ms preprocess, 82.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.7ms preprocess, 87.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.7ms
# Speed: 2.1ms preprocess, 83.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.4ms
# Speed: 2.7ms preprocess, 89.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.3ms preprocess, 85.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.5ms preprocess, 86.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.2ms preprocess, 86.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.0ms
# Speed: 2.5ms preprocess, 93.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.5ms
# Speed: 2.4ms preprocess, 90.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.8ms
# Speed: 2.5ms preprocess, 87.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.6ms
# Speed: 2.1ms preprocess, 82.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 4.9ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.6ms preprocess, 84.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.7ms
# Speed: 1.9ms preprocess, 83.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.9ms
# Speed: 2.0ms preprocess, 81.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 79.0ms
# Speed: 2.1ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.3ms preprocess, 86.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.5ms preprocess, 86.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.8ms
# Speed: 2.3ms preprocess, 83.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.5ms preprocess, 87.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.9ms
# Speed: 2.4ms preprocess, 81.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.6ms
# Speed: 2.5ms preprocess, 83.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.6ms
# Speed: 7.0ms preprocess, 87.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.6ms
# Speed: 2.8ms preprocess, 89.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.8ms
# Speed: 2.7ms preprocess, 87.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.5ms
# Speed: 2.5ms preprocess, 92.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.8ms
# Speed: 2.1ms preprocess, 82.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.4ms preprocess, 86.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.4ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.1ms
# Speed: 2.5ms preprocess, 89.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.9ms
# Speed: 2.0ms preprocess, 82.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.6ms
# Speed: 2.2ms preprocess, 88.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.1ms
# Speed: 2.4ms preprocess, 87.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.6ms
# Speed: 2.6ms preprocess, 87.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.1ms
# Speed: 2.4ms preprocess, 85.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 2.6ms preprocess, 88.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.4ms preprocess, 86.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.4ms
# Speed: 2.4ms preprocess, 84.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.8ms
# Speed: 2.6ms preprocess, 82.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.6ms
# Speed: 2.5ms preprocess, 92.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.4ms
# Speed: 2.7ms preprocess, 91.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.9ms
# Speed: 2.1ms preprocess, 93.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.3ms preprocess, 87.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.5ms
# Speed: 2.8ms preprocess, 89.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.9ms
# Speed: 2.8ms preprocess, 88.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.0ms
# Speed: 2.3ms preprocess, 91.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.5ms
# Speed: 2.6ms preprocess, 84.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.2ms
# Speed: 1.9ms preprocess, 84.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.5ms preprocess, 86.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.1ms
# Speed: 1.8ms preprocess, 87.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.7ms
# Speed: 2.1ms preprocess, 83.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.7ms preprocess, 88.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.3ms preprocess, 87.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.5ms preprocess, 86.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.4ms preprocess, 86.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.5ms
# Speed: 2.4ms preprocess, 85.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.6ms preprocess, 86.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.9ms
# Speed: 2.4ms preprocess, 92.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.4ms preprocess, 86.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# Speed: 2.6ms preprocess, 87.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.5ms
# Speed: 2.5ms preprocess, 89.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.9ms
# Speed: 2.4ms preprocess, 86.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.2ms
# Speed: 2.2ms preprocess, 85.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.3ms
# Speed: 3.1ms preprocess, 84.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.7ms
# Speed: 2.5ms preprocess, 84.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.2ms
# Speed: 2.6ms preprocess, 83.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.9ms
# Speed: 2.3ms preprocess, 83.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.6ms
# Speed: 2.8ms preprocess, 85.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.3ms
# Speed: 2.3ms preprocess, 87.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.9ms
# Speed: 2.1ms preprocess, 83.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.3ms preprocess, 86.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.3ms
# Speed: 2.4ms preprocess, 87.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.2ms
# Speed: 2.4ms preprocess, 88.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.5ms
# Speed: 2.7ms preprocess, 85.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.1ms
# Speed: 2.4ms preprocess, 84.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.4ms
# Speed: 2.3ms preprocess, 92.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.7ms
# Speed: 2.5ms preprocess, 88.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 1.9ms preprocess, 88.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.5ms
# Speed: 2.2ms preprocess, 84.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.8ms
# Speed: 2.3ms preprocess, 84.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.8ms
# Speed: 2.1ms preprocess, 87.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.4ms
# Speed: 2.5ms preprocess, 92.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.4ms
# Speed: 2.2ms preprocess, 83.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 1.9ms preprocess, 85.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.4ms
# Speed: 2.2ms preprocess, 85.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.6ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.6ms
# Speed: 2.2ms preprocess, 88.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.7ms
# Speed: 2.4ms preprocess, 81.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.0ms
# Speed: 2.4ms preprocess, 86.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.8ms
# Speed: 2.4ms preprocess, 85.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.2ms
# Speed: 2.4ms preprocess, 89.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.5ms preprocess, 89.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.4ms
# Speed: 2.9ms preprocess, 91.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 2.1ms preprocess, 85.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.4ms preprocess, 86.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.3ms
# Speed: 2.6ms preprocess, 88.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.8ms
# Speed: 2.4ms preprocess, 82.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.4ms preprocess, 84.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.4ms
# Speed: 2.3ms preprocess, 91.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.7ms
# Speed: 2.7ms preprocess, 91.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.8ms
# Speed: 2.5ms preprocess, 89.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.9ms
# Speed: 2.1ms preprocess, 89.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.6ms preprocess, 84.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.1ms
# Speed: 2.8ms preprocess, 82.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.5ms
# Speed: 2.3ms preprocess, 85.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.3ms
# Speed: 1.8ms preprocess, 85.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.4ms preprocess, 88.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.7ms
# Speed: 2.3ms preprocess, 86.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.1ms
# Speed: 2.6ms preprocess, 88.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.8ms
# Speed: 2.3ms preprocess, 82.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 1.8ms preprocess, 84.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.2ms preprocess, 88.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.5ms
# Speed: 2.5ms preprocess, 88.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.2ms preprocess, 86.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.0ms
# Speed: 2.3ms preprocess, 84.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# ...
# Speed: 2.4ms preprocess, 90.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.5ms preprocess, 89.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.6ms
# Speed: 2.5ms preprocess, 90.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.2ms
# Speed: 2.7ms preprocess, 88.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.7ms
# Speed: 2.4ms preprocess, 87.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.4ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.4ms
# Speed: 2.5ms preprocess, 85.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.8ms
# Speed: 1.9ms preprocess, 81.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.8ms
# Speed: 3.1ms preprocess, 88.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.0ms
# Speed: 2.4ms preprocess, 86.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.5ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.1ms
# Speed: 3.7ms preprocess, 90.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.7ms preprocess, 86.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.5ms
# Speed: 2.5ms preprocess, 83.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.6ms
# Speed: 2.5ms preprocess, 88.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.3ms preprocess, 87.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.6ms preprocess, 86.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.2ms
# Speed: 2.4ms preprocess, 91.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.0ms
# Speed: 2.7ms preprocess, 89.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.2ms
# Speed: 2.4ms preprocess, 90.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.7ms
# Speed: 2.5ms preprocess, 88.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.6ms
# Speed: 2.5ms preprocess, 89.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.0ms
# Speed: 2.5ms preprocess, 89.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.4ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.5ms
# Speed: 1.8ms preprocess, 89.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.4ms preprocess, 86.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.8ms
# Speed: 2.6ms preprocess, 84.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.9ms
# Speed: 2.2ms preprocess, 82.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.1ms
# Speed: 1.9ms preprocess, 89.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.5ms
# Speed: 2.7ms preprocess, 84.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.3ms preprocess, 86.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.3ms preprocess, 86.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.5ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.4ms
# Speed: 2.3ms preprocess, 81.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.3ms
# Speed: 2.1ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.4ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.9ms
# Speed: 2.0ms preprocess, 84.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.1ms
# Speed: 2.4ms preprocess, 87.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.7ms
# Speed: 2.1ms preprocess, 87.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.3ms
# Speed: 2.4ms preprocess, 81.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 78.3ms
# Speed: 2.1ms preprocess, 78.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.2ms
# Speed: 2.4ms preprocess, 87.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.8ms
# Speed: 2.6ms preprocess, 84.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.7ms
# Speed: 1.9ms preprocess, 81.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.4ms
# Speed: 2.4ms preprocess, 85.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# Speed: 1.9ms preprocess, 87.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.6ms
# Speed: 2.5ms preprocess, 83.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.7ms
# Speed: 2.7ms preprocess, 84.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.4ms preprocess, 86.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.0ms
# Speed: 2.6ms preprocess, 85.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.3ms
# Speed: 1.8ms preprocess, 87.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.6ms
# Speed: 2.5ms preprocess, 85.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.0ms
# Speed: 4.3ms preprocess, 85.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.6ms
# Speed: 2.6ms preprocess, 87.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 2.7ms preprocess, 84.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.1ms
# Speed: 2.1ms preprocess, 88.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.1ms
# Speed: 2.2ms preprocess, 86.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.1ms preprocess, 88.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 105.2ms
# Speed: 4.2ms preprocess, 105.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.4ms
# Speed: 2.1ms preprocess, 85.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.4ms
# Speed: 2.3ms preprocess, 88.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.4ms preprocess, 86.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.4ms
# Speed: 2.7ms preprocess, 86.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.9ms
# Speed: 2.6ms preprocess, 87.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.9ms
# Speed: 3.0ms preprocess, 89.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 93.5ms
# Speed: 2.7ms preprocess, 93.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.4ms
# Speed: 2.5ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.6ms
# Speed: 2.4ms preprocess, 87.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.2ms
# Speed: 2.7ms preprocess, 83.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 80.2ms
# Speed: 2.4ms preprocess, 80.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.7ms
# Speed: 4.7ms preprocess, 85.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.1ms
# Speed: 2.5ms preprocess, 85.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 92.4ms
# Speed: 2.4ms preprocess, 92.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.7ms
# Speed: 2.4ms preprocess, 89.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.9ms
# Speed: 2.5ms preprocess, 90.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.9ms
# Speed: 2.3ms preprocess, 91.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.7ms
# Speed: 2.5ms preprocess, 90.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 2.8ms preprocess, 86.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.0ms
# Speed: 2.2ms preprocess, 85.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.2ms
# Speed: 2.7ms preprocess, 85.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.4ms
# Speed: 1.9ms preprocess, 83.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.2ms
# Speed: 2.4ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.8ms
# Speed: 2.3ms preprocess, 86.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.4ms
# Speed: 2.8ms preprocess, 85.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.0ms
# Speed: 2.4ms preprocess, 83.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.1ms preprocess, 89.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 94.0ms
# Speed: 2.3ms preprocess, 94.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.5ms
# Speed: 2.6ms preprocess, 82.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.8ms
# Speed: 3.1ms preprocess, 85.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.6ms
# Speed: 2.4ms preprocess, 88.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 87.1ms
# Speed: 2.3ms preprocess, 87.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.8ms
# Speed: 2.9ms preprocess, 83.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 80.6ms
# Speed: 3.4ms preprocess, 80.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 84.6ms
# Speed: 2.4ms preprocess, 84.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 81.0ms
# Speed: 2.5ms preprocess, 81.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.6ms
# Speed: 2.5ms preprocess, 86.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.9ms
# Speed: 2.4ms preprocess, 83.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.9ms
# Speed: 2.4ms preprocess, 82.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.6ms
# Speed: 2.3ms preprocess, 89.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.0ms
# Speed: 2.5ms preprocess, 85.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.5ms
# Speed: 2.2ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 80.9ms
# Speed: 2.4ms preprocess, 80.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 82.7ms
# Speed: 2.3ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.2ms
# Speed: 2.6ms preprocess, 83.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.3ms
# Speed: 2.1ms preprocess, 83.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.4ms preprocess, 86.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.1ms
# Speed: 2.4ms preprocess, 85.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.7ms
# Speed: 1.9ms preprocess, 90.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.5ms
# Speed: 2.3ms preprocess, 91.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.3ms
# Speed: 2.3ms preprocess, 89.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.5ms
# Speed: 2.4ms preprocess, 89.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.1ms preprocess, 86.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 83.6ms
# Speed: 2.4ms preprocess, 83.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.3ms
# Speed: 2.4ms preprocess, 86.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 85.7ms
# Speed: 2.6ms preprocess, 85.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
count
# Out:
# 3

# %%
pose_results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         [[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         [[229, 209, 199],
#          [230, 210, 200],
#          [231, 213, 205],
#          ...,
#          [116, 113, 114],
#          [114, 111, 112],
#          [114, 111, 112]],
#
#         ...,
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]],
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]],
#
#         [[ 12,  13,   8],
#          [ 15,  16,  11],
#          [ 20,  21,  16],
#          ...,
#          [149, 149, 149],
#          [149, 149, 149],
#          [149, 149, 149]]], dtype=uint8)
#  orig_shape: (1280, 720)
#  path: 'image0.jpg'
#  probs: None
#  save_dir: 'runs\\pose\\predict'
#  speed: {'preprocess': 1.43420000676997, 'inference': 50.18019999261014, 'postprocess': 0.9157000167760998}]

# %%
pose_results[0].keypoints.data
# Out:
# tensor([[[3.4592e+02, 4.7591e+02, 9.8805e-01],
#          [3.6553e+02, 4.5869e+02, 9.8924e-01],
#          [3.3415e+02, 4.5857e+02, 8.8440e-01],
#          [4.0683e+02, 4.6538e+02, 9.7442e-01],
#          [0.0000e+00, 0.0000e+00, 2.4847e-01],
#          [4.5739e+02, 5.7038e+02, 9.9882e-01],
#          [3.1205e+02, 5.6708e+02, 9.9058e-01],
#          [4.9573e+02, 7.0065e+02, 9.9370e-01],
#          [2.9750e+02, 6.8727e+02, 8.9018e-01],
#          [5.1039e+02, 8.0501e+02, 9.8697e-01],
#          [2.9840e+02, 7.9071e+02, 8.7687e-01],
#          [4.2727e+02, 8.2340e+02, 9.9978e-01],
#          [3.3304e+02, 8.1967e+02, 9.9932e-01],
#          [4.1431e+02, 1.0005e+03, 9.9949e-01],
#          [3.1224e+02, 9.9912e+02, 9.9853e-01],
#          [4.0342e+02, 1.1516e+03, 9.9587e-01],
#          [3.2327e+02, 1.1519e+03, 9.9239e-01]]])

# %%
keypoints = torch.tensor(pose_results[0].keypoints.xy)
keypoints[0]
# Out:
# C:\Users\Roydon\AppData\Local\Temp\ipykernel_29652\986057603.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   keypoints = torch.tensor(pose_results[0].keypoints.xy)
# tensor([[ 348.8192,  477.1858],
#         [ 368.5421,  460.0144],
#         [ 336.8237,  459.9761],
#         [ 409.4200,  467.1314],
#         [   0.0000,    0.0000],
#         [ 459.3442,  572.5975],
#         [ 314.8810,  570.4692],
#         [ 500.3615,  701.1915],
#         [ 299.0328,  689.4351],
#         [ 520.6007,  804.6921],
#         [ 292.0893,  789.7985],
#         [ 429.0633,  822.0613],
#         [ 336.0569,  818.5392],
#         [ 416.3361,  999.4310],
#         [ 316.2916,  998.3321],
#         [ 403.8281, 1147.8667],
#         [ 327.6841, 1148.2466]])

# %%
left_shoulder = keypoints[0,5]
right_shoulder = keypoints[0,6]
left_ankle = keypoints[0,15]
right_ankle = keypoints[0,16]

# %%
right_ankle[1].item()
# Out:
# 1148.24658203125
